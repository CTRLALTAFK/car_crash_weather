# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# Files to Load
file = "Resources/crash_weather_full2.csv"

# %%
# Read the csv file and store into Pandas DataFrame
combined_df = pd.read_csv(file)
combined_df.head()
# Out:
#    tamainid                   location_description        road_feature  \
# 0   10763.0        110 FEET FROM JAMES JACKSON AVE  NO SPECIAL FEATURE
# 1   10766.0         NEAR .5 MILES S OF S NC 55 HWY  NO SPECIAL FEATURE
# 2   10781.0                  .09 MILES FROM US-1 S  NO SPECIAL FEATURE
# 3   10803.0  250 FEET FROM PVA 201 CROSSROADS BLVD    DRIVEWAY, PUBLIC
# 4   10809.0                   250 FEET FROM SR1415  NO SPECIAL FEATURE
#
#    road_character             road_class  \
# 0  STRAIGHT,GRADE           LOCAL STREET
# 1  STRAIGHT,LEVEL               NC ROUTE
# 2  STRAIGHT,LEVEL               US ROUTE
# 3  STRAIGHT,LEVEL  PUBLIC VEHICULAR AREA
# 4  STRAIGHT,GRADE  STATE SECONDARY ROUTE
#
#                         road_configuration    road_surface road_conditions  \
# 0       TWO-WAY,DIVIDED,UNPROTECTED MEDIAN  SMOOTH ASPHALT             DRY
# 1                      TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT             WET
# 2  TWO-WAY,DIVIDED,POSITIVE MEDIAN BARRIER  SMOOTH ASPHALT             DRY
# 3                      TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT             DRY
# 4                      TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT             DRY
#
#           light_condition weather  ... drizzle  snow  freezingrain  smokehaze  \
# 0  DARK - LIGHTED ROADWAY  CLOUDY  ...       f     f             f          f
# 1                DAYLIGHT    RAIN  ...       f     f             f          f
# 2  DARK - LIGHTED ROADWAY   CLEAR  ...       f     f             f          f
# 3  DARK - LIGHTED ROADWAY   CLEAR  ...       f     f             f          f
# 4                DAYLIGHT   CLEAR  ...       f     f             f          f
#
#    thunder  highwind  hail  blowingsnow  dust freezingfog
# 0        f         f     f            f     f           f
# 1        f         f     f            f     f           f
# 2        f         f     f            f     f           f
# 3        f         f     f            f     f           f
# 4        f         f     f            f     f           f
#
# [5 rows x 49 columns]

# %%
# Rename Column Titles
update = combined_df.rename(columns={'road_feature': 'Road Feature', 'road_class': 'Road Class',
                                     'location_description': 'Location', 'road_configuration': 'Configuration',
                                     'road_character': 'Character', 'road_surface': 'Surface',
                                     'light_condition': 'Light Condition','road_conditions': 'Road Condition',
                                     'tamainid': 'ID','traffic_control': 'Traffic Control','weather': 'Weather',
                                     'lat': 'Latitude','lon': 'Longitude','lat2': 'Latitude2','lon2': 'Longitude2',
                                     'fatality': 'Fatalities','injury': 'Injuries','date': 'Date'})
update.head()
# Out:
#         ID                               Location        Road Feature  \
# 0  10763.0        110 FEET FROM JAMES JACKSON AVE  NO SPECIAL FEATURE
# 1  10766.0         NEAR .5 MILES S OF S NC 55 HWY  NO SPECIAL FEATURE
# 2  10781.0                  .09 MILES FROM US-1 S  NO SPECIAL FEATURE
# 3  10803.0  250 FEET FROM PVA 201 CROSSROADS BLVD    DRIVEWAY, PUBLIC
# 4  10809.0                   250 FEET FROM SR1415  NO SPECIAL FEATURE
#
#         Character             Road Class  \
# 0  STRAIGHT,GRADE           LOCAL STREET
# 1  STRAIGHT,LEVEL               NC ROUTE
# 2  STRAIGHT,LEVEL               US ROUTE
# 3  STRAIGHT,LEVEL  PUBLIC VEHICULAR AREA
# 4  STRAIGHT,GRADE  STATE SECONDARY ROUTE
#
#                              Configuration         Surface Road Condition  \
# 0       TWO-WAY,DIVIDED,UNPROTECTED MEDIAN  SMOOTH ASPHALT            DRY
# 1                      TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT            WET
# 2  TWO-WAY,DIVIDED,POSITIVE MEDIAN BARRIER  SMOOTH ASPHALT            DRY
# 3                      TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT            DRY
# 4                      TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT            DRY
#
#           Light Condition Weather  ... drizzle  snow  freezingrain  smokehaze  \
# 0  DARK - LIGHTED ROADWAY  CLOUDY  ...       f     f             f          f
# 1                DAYLIGHT    RAIN  ...       f     f             f          f
# 2  DARK - LIGHTED ROADWAY   CLEAR  ...       f     f             f          f
# 3  DARK - LIGHTED ROADWAY   CLEAR  ...       f     f             f          f
# 4                DAYLIGHT   CLEAR  ...       f     f             f          f
#
#    thunder  highwind  hail  blowingsnow  dust freezingfog
# 0        f         f     f            f     f           f
# 1        f         f     f            f     f           f
# 2        f         f     f            f     f           f
# 3        f         f     f            f     f           f
# 4        f         f     f            f     f           f
#
# [5 rows x 49 columns]

# %%
# Add Value Column
update['Value'] = 1
update
# Out:
#             ID                               Location        Road Feature  \
# 0      10763.0        110 FEET FROM JAMES JACKSON AVE  NO SPECIAL FEATURE
# 1      10766.0         NEAR .5 MILES S OF S NC 55 HWY  NO SPECIAL FEATURE
# 2      10781.0                  .09 MILES FROM US-1 S  NO SPECIAL FEATURE
# 3      10803.0  250 FEET FROM PVA 201 CROSSROADS BLVD    DRIVEWAY, PUBLIC
# 4      10809.0                   250 FEET FROM SR1415  NO SPECIAL FEATURE
# ...        ...                                    ...                 ...
# 30191      NaN                                    NaN                 NaN
# 30192      NaN                                    NaN                 NaN
# 30193      NaN                                    NaN                 NaN
# 30194      NaN                                    NaN                 NaN
# 30195      NaN                                    NaN                 NaN
#
#             Character             Road Class  \
# 0      STRAIGHT,GRADE           LOCAL STREET
# 1      STRAIGHT,LEVEL               NC ROUTE
# 2      STRAIGHT,LEVEL               US ROUTE
# 3      STRAIGHT,LEVEL  PUBLIC VEHICULAR AREA
# 4      STRAIGHT,GRADE  STATE SECONDARY ROUTE
# ...               ...                    ...
# 30191             NaN                    NaN
# 30192             NaN                    NaN
# 30193             NaN                    NaN
# 30194             NaN                    NaN
# 30195             NaN                    NaN
#
#                                  Configuration         Surface Road Condition  \
# 0           TWO-WAY,DIVIDED,UNPROTECTED MEDIAN  SMOOTH ASPHALT            DRY
# 1                          TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT            WET
# 2      TWO-WAY,DIVIDED,POSITIVE MEDIAN BARRIER  SMOOTH ASPHALT            DRY
# 3                          TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT            DRY
# 4                          TWO-WAY,NOT DIVIDED  SMOOTH ASPHALT            DRY
# ...                                        ...             ...            ...
# 30191                                      NaN             NaN            NaN
# 30192                                      NaN             NaN            NaN
# 30193                                      NaN             NaN            NaN
# 30194                                      NaN             NaN            NaN
# 30195                                      NaN             NaN            NaN
#
#               Light Condition Weather  ... snow  freezingrain  smokehaze  \
# 0      DARK - LIGHTED ROADWAY  CLOUDY  ...    f             f          f
# 1                    DAYLIGHT    RAIN  ...    f             f          f
# 2      DARK - LIGHTED ROADWAY   CLEAR  ...    f             f          f
# 3      DARK - LIGHTED ROADWAY   CLEAR  ...    f             f          f
# 4                    DAYLIGHT   CLEAR  ...    f             f          f
# ...                       ...     ...  ...  ...           ...        ...
# 30191                     NaN     NaN  ...    f             f          f
# 30192                     NaN     NaN  ...    f             f          t
# 30193                     NaN     NaN  ...    f             f          t
# 30194                     NaN     NaN  ...    f             f          f
# 30195                     NaN     NaN  ...    f             f          f
#
#        thunder  highwind  hail  blowingsnow  dust  freezingfog Value
# 0            f         f     f            f     f            f     1
# 1            f         f     f            f     f            f     1
# 2            f         f     f            f     f            f     1
# 3            f         f     f            f     f            f     1
# 4            f         f     f            f     f            f     1
# ...        ...       ...   ...          ...   ...          ...   ...
# 30191        f         f     f            f     f            f     1
# 30192        f         f     f            f     f            f     1
# 30193        f         f     f            t     f            f     1
# 30194        f         f     f            f     f            f     1
# 30195        f         f     f            f     f            f     1
#
# [30196 rows x 50 columns]

# %%
# Group together same Lighting Conditions to reflect in "Value" column
new_df = update.groupby('Light Condition').sum().reset_index()
new_df.head()
# Out:
#               Light Condition           ID       Latitude      Longitude  \
# 0      DARK - LIGHTED ROADWAY   94203812.0   49952.115498 -109994.096349
# 1  DARK - ROADWAY NOT LIGHTED   20797430.0   12663.944000  -27898.094354
# 2     DARK - UNKNOWN LIGHTING    1681754.0     966.456798   -2127.804150
# 3                        DAWN    4606934.0    2218.705674   -4885.961592
# 4                    DAYLIGHT  572408846.0  278381.186254 -613105.899215
#
#      Longitude2     Latitude2  Fatalities  Injuries  numpassengers  \
# 0 -8.593052e+07  6.691883e+07         7.0     658.0         2134.0
# 1 -7.811196e+07  3.986796e+07         5.0     156.0          402.0
# 2 -7.481023e+05  2.069216e+06         0.0       8.0           20.0
# 3 -1.549197e+06  2.074082e+06         1.0      25.0          112.0
# 4 -1.269911e+09  6.352617e+08        18.0    3940.0        14248.0
#
#    numpedestrians  temperaturemin  temperaturemax  precipitation  snowfall  \
# 0            28.0        166741.8        239336.0         603.88     57.99
# 1            10.0         38332.5         54367.3         161.09     16.19
# 2             1.0          2601.9          3797.5           9.83      1.61
# 3             2.0          7711.9         11152.2          26.34      1.62
# 4           112.0       1139400.6       1594943.3        3090.34    367.44
#
#    snowdepth  avgwindspeed  Value
# 0      79.51      20690.54   3599
# 1      22.83       4656.89    801
# 2       2.36        299.06     58
# 3       4.33        996.56    164
# 4     308.59     125537.29  21489

# %%
# Plot Data
new_df.plot(x='Light Condition', y='Injuries', grid=True, figsize=(25,25)  )

# %%
# Modify Text and Font Sizes
new_df.set_index('Light Condition')['Injuries'].plot(figsize=(25, 25), linewidth=2, color='green')
plt.xlabel("Visibility/Lighting", labelpad=50, fontsize=50)
plt.ylabel("Injuries", labelpad=15, fontsize=50)
plt.title("Injuries with Different Visibilities - Overall", y=1, fontsize=80)
plt.savefig("Images/Injuries.png")
;
# Out:
# ''
